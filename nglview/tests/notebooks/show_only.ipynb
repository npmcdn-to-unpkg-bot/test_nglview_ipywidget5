# %%
import nglview as nv
import pytraj as pt

view = nv.NGLWidget()
view

# %%
view.add_component(nv.datafiles.PDB)

# %%
view.add_trajectory(pt.datafiles.load_tz2())

# %%
view.orientation = [[-44.05654080809422, 53.33969143535392, -31.262908305067885],
 [-0.690050723850951, -0.23235797089088295, 0.6854485917092916],
 [-25.576396465301514, -26.334304332733154, -38.50318503379822],
 [-0.9167753331786093, -3.722447005661373, -7.176807772413017]]

# %%
# hide bigger protein
view.hide([0,])

# %%
view.render_image()

# %%
view._display_image()

# %%
# show only bigger protein
view.show_only([0,])

# %%
view.render_image()

# %%
view._display_image()

# %%
# show all
view.show_only('all')

# %%
view.render_image()

# %%
view._display_image()

# %%
# hide all
view.hide([0, 1])

# %%
view.render_image()

# %%
view._display_image()

# %%
# show last
view.show([1])

# %%
view.render_image()

# %%
view._display_image()

# %%
# show all again

view.show()

# %%
view.render_image()

# %%
view._display_image()
